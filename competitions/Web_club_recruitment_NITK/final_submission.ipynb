# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df_train = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_train.head()
columns = df_train.columns
#columns

# %%
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('train -> x1 distributions', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_train['X1'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('train-> After log transformation', 
             fontsize=12)
df_train['X1']= np.log(1+df_train['X1'])

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_train['X1'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#for test
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('test -> x1 distributions', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_test['X1'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('test-> After log transformation', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_test['X1']= np.log(1+df_test['X1'])
df_test['X1'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
length = 14 # 14 - 8
length -= 1
label_for_x1 = [k for k in range(length)]

# %%
#handling the categorical data
array_having_bit = np.linspace(8,14,length+1)

# %%
#binning the data
df_train['X1'] = pd.cut(df_train['X1'], array_having_bit,labels = label_for_x1)

# %%
# X5
#X5 column data is distributed
fig, ax = plt.subplots()
ax.set_title('train -> x5 distributions', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_train['X5'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('train-> After log transformation', 
             fontsize=12)
df_train['X5']= np.log(1+df_train['X5'])

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_train['X5'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#for test
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('test -> x5 distributions', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_test['X5'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#lets see how our X1 column data is distributed
fig, ax = plt.subplots()
ax.set_title('test-> After log transformation', 
             fontsize=12)

ax.set_xlabel('Actual Values', fontsize=12)
ax.set_ylabel('Frequency', fontsize=12)
df_test['X5']= np.log(1+df_test['X5'])
df_test['X5'].hist(bins=25,color='#A9C5D3',edgecolor='black', grid=False)

# %%
#Binning for X5
#same as above for x1
length = 24-1
array_having_bit = np.linspace(3 ,4.4,length+1)
label_for_x5 = [ k for k in range(length)]

# %%
df_train['X5'] = pd.cut(df_train['X5'],bins = array_having_bit, labels = label_for_x5 )

# %%
#separating the features and outcomes
x = df_train.iloc[: , :24]
y = df_train.iloc[ : , 24]

# %%
x = x.drop('id',1)
df_test = df_test.drop('id',1)

# %%
#to see the accuracy...
#x_train,x_test,y_train,y_test = train_test_split(x,y,random_state =1, test_size =0.3)

# %%
# Feature Selection

# manually finding the importance of each feature
"""
len = x_train.shape[1]
accuracy = [] # after dropping each column storing the accuracy
r2 = []  # this stores the r2_score
for i in range(1,10):
    xtrain = x_train.drop(columns[i],1) #dropped the ith column
    xtest = x_test.drop(columns[i],1)   #same for test 
    clf.fit(xtrain,y_train)             #fit with dropped column  
    ypredict = clf.predict(xtest)       
    score = r2_score(np.array(ypredict),y_test)
    r2.append((score,columns[i]))
    score = accuracy_score(np.array(ypredict),y_test)
    accuracy.append((score,columns[i]))
print("according to accuracy ")
print(accuracy)
print("according to r2 ")
print(r2)
"""

#r2 score was negative ,,,,don't know how r2 score is calculated ,,,some blog stated that r2 can be negative
# Out:
# '\nlen = x_train.shape[1]\naccuracy = [] # after dropping each column storing the accuracy\nr2 = []  # this stores the r2_score\nfor i in range(1,10):\n    xtrain = x_train.drop(columns[i],1) #dropped the ith column\n    xtest = x_test.drop(columns[i],1)   #same for test \n    clf.fit(xtrain,y_train)             #fit with dropped column  \n    ypredict = clf.predict(xtest)       \n    score = r2_score(np.array(ypredict),y_test)\n    r2.append((score,columns[i]))\n    score = accuracy_score(np.array(ypredict),y_test)\n    accuracy.append((score,columns[i]))\nprint("according to accuracy ")\nprint(accuracy)\nprint("according to r2 ")\nprint(r2)\n'

# %%
#tried to drop the X6 column but no improvement in the final standings of comp.

'''
df_train.isnull().sum()
x6 is being removed
x = x.drop('X6',1)
df_test = df_test.drop('X6',1)
x = x.drop('id',1)
df_test = df_test.drop('id',1)
x_train.head
'''
# Out:
# "\ndf_train.isnull().sum()\nx6 is being removed\nx = x.drop('X6',1)\ndf_test = df_test.drop('X6',1)\nx = x.drop('id',1)\ndf_test = df_test.drop('id',1)\nx_train.head\n"

# %%
# submitted file has n_esitmators = 1000
clf = RandomForestClassifier(n_estimators = 30 , max_depth = 20 , random_state = 123, max_features = 0.2)
clf.fit(x,y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features=0.2, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=30, n_jobs=1,
#             oob_score=False, random_state=123, verbose=0, warm_start=False)

# %%
y_predict = clf.predict(df_test)

# %%
#training our model
'''
clf = RandomForestClassifier(n_estimators = 1000 , max_depth = 20,random_state = 123,max_features = 0.2)
clf.fit(x_train,y_train)
'''
# Out:
# '\nclf = RandomForestClassifier(n_estimators = 1000 , max_depth = 20,random_state = 123,max_features = 0.2)\nclf.fit(x_train,y_train)\n'

# %%
#y_predict = clf.predict_proba(df_test)

# %%
#writing into the file
result = pd.DataFrame(y_predict)
result.index.name = 'id'
result.columns = ['predicted_val']
result.to_csv('output.csv', index=True)

# %%
#df_train.head(50)
